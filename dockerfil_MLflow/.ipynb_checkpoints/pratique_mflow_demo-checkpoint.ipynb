# %%
#!pip install mlflow

# %%
#conda create -n mlflow_envy

# %%
#conda activate mlflow_env

# %%
# The data set used in this example is from http://archive.ics.uci.edu/ml/datasets/Wine+Quality
# P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
# Modeling wine preferences by data mining from physicochemical properties. In Decision Support Systems, Elsevier, 47(4):547-553, 2009.
#! pip install --user mlflow
 
import os
import warnings
import sys
 
import pandas as pd

import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
 
import mlflow
import mlflow.sklearn
 
import logging
logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)
 
 
def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2
 
 
 
if __name__ == "__main__":
    
    warnings.filterwarnings("ignore")
    np.random.seed(40)
 
    # Read the wine-quality csv file from the URL
    csv_url =\
        'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
    try:
        data = pd.read_csv(csv_url, sep=';')
    except Exception as e:
        logger.exception(
            "Unable to download training & test CSV, check your internet connection. Error: %s", e)
 
    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)
 
    # The predicted column is "quality" which is a scalar from !pip install mlflow[3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]
 
    #alpha = float(sys.argv[1]) if len(sys.argv) > 1 else 0.5
    #l1_ratio = float(sys.argv[2]) if len(sys.argv) > 2 else 0.5
    alpha = 0.65#à changer
    l1_ratio = 0.82#à changer
 
    with mlflow.start_run():
        mlflow.set_experiment(experiment_name="mlflow_CI_CD")
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)
 
        predicted_qualities = lr.predict(test_x)
 
        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)
 
        print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, l1_ratio))
        print("  RMSE: %s" % rmse)
        print("  MAE: %s" % mae)
        print("  R2: %s" % r2)
 
        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1_ratio)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)
 
        mlflow.sklearn.log_model(lr, "model")
        print(f"artifact_uri={mlflow.get_artifact_uri()}")
        #print(f"run_id={run_id}")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# <ipython-input-12-accdab06fa2b> in <module>
#      59     l1_ratio = 0.82#à changer
#      60
# ---> 61     with mlflow.start_run():
#      62 #         mlflow.set_experiment(experiment_name="mlflow_CI_CD")
#      63         lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
#
# ~/anaconda3/envs/tensorflow-gpu/lib/python3.8/site-packages/mlflow/tracking/fluent.py in start_run(run_id, experiment_id, run_name, nested, tags)
#     225         tags = context_registry.resolve_tags(user_specified_tags)
#     226
# --> 227         active_run_obj = MlflowClient().create_run(experiment_id=exp_id_for_run, tags=tags)
#     228
#     229     _active_run_stack.append(ActiveRun(active_run_obj))
#
# ~/anaconda3/envs/tensorflow-gpu/lib/python3.8/site-packages/mlflow/tracking/client.py in create_run(self, experiment_id, start_time, tags)
#     250             status: RUNNING
#     251         """
# --> 252         return self._tracking_client.create_run(experiment_id, start_time, tags)
#     253
#     254     def list_run_infos(
#
# ~/anaconda3/envs/tensorflow-gpu/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/client.py in create_run(self, experiment_id, start_time, tags)
#      87         user_id = tags.get(MLFLOW_USER, "unknown")
#      88
# ---> 89         return self.store.create_run(
#      90             experiment_id=experiment_id,
#      91             user_id=user_id,
#
# ~/anaconda3/envs/tensorflow-gpu/lib/python3.8/site-packages/mlflow/store/tracking/file_store.py in create_run(self, experiment_id, user_id, start_time, tags)
#     453         """
#     454         experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> 455         experiment = self.get_experiment(experiment_id)
#     456         if experiment is None:
#     457             raise MlflowException(
#
# ~/anaconda3/envs/tensorflow-gpu/lib/python3.8/site-packages/mlflow/store/tracking/file_store.py in get_experiment(self, experiment_id)
#     334         """
#     335         experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> 336         experiment = self._get_experiment(experiment_id)
#     337         if experiment is None:
#     338             raise MlflowException(
#
# ~/anaconda3/envs/tensorflow-gpu/lib/python3.8/site-packages/mlflow/store/tracking/file_store.py in _get_experiment(self, experiment_id, view_type)
#     303         experiment_dir = self._get_experiment_path(experiment_id, view_type)
#     304         if experiment_dir is None:
# --> 305             raise MlflowException(
#     306                 "Could not find experiment with ID %s" % experiment_id,
#     307                 databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#
# MlflowException: Could not find experiment with ID 1
